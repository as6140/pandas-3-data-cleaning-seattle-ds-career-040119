# %% [markdown]
# # Data Cleaning with Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Scenario
#
# As data scientists, we want to build a model to predict the sale price of a house in Seattle in 2019, based on its square footage. We know that the King County Department of Assessments has comprehensive data available on real property sales in the Seattle area. We need to prepare the data.

# %%
# !cd data

# %%
# !ls
# Out:
# README.md                    data
# Real Property Sales.zip      pandas-3-data-cleaning.ipynb
# Real Property Sales.zip.1    wget-log
# Residential Building.zip     wget-log.1

# %%
#!brew install wget

# %%
#!wget https://aqua.kingcounty.gov/extranet/assessor/Real%20Property%20Sales.zip

# %%
#!wget https://aqua.kingcounty.gov/extranet/assessor/Residential%20Building.zip
    #web client that runs on command line that can download files

# %%
# !cd data

# %%
# !ls
# Out:
# README.md                    data
# Real Property Sales.zip      pandas-3-data-cleaning.ipynb
# Real Property Sales.zip.1    wget-log
# Residential Building.zip     wget-log.1

# %% [markdown]
# ### First, get the data!
#
# When working on a project involving data that can fit on our computer, we store it in a `data` directory.
#
# ```bash
# cd <project_directory>  # example: cd ~/flatiron_ds/pandas-3
# mkdir data
# cd data
# ```
#
# Note that `<project_directory>` in angle brackets is a _placeholder_. You should type the path to the actual location on your computer where you're working on this project. Do not literally type `<project_directory>` and _do not type the angle brackets_. You can see an example in the _comment_ to the right of the command above.
#
# Now, we'll need to download the two data files that we need. We can do this at the command line:
#
# ```bash
# wget https://aqua.kingcounty.gov/extranet/assessor/Real%20Property%20Sales.zip
# wget https://aqua.kingcounty.gov/extranet/assessor/Residential%20Building.zip
# ```
#
# *Note:* If you do not have the `wget` command yet, you can install it: `brew install wget`.
#
# Note that `%20` in a URL translates into a space. Even though you will *never put spaces in filenames*, you may need to deal with spaces that _other_ people have used in filenames.
#
# There are two ways to handle the spaces in these filenames when referencing them at the command line.
#
# #### 1. You can _escape_ the spaces by putting a backslash (`\`, remember _backslash is next to backspace_) before each one:
#
# `unzip Real\ Property\ Sales.zip`
#
# This is what happens if you tab-complete the filename in the terminal. Tab completion is your friend!
#
# #### 2. You can put the entire filename in quotes:
#
# `unzip "Real Property Sales.zip"`
#
# Try unzipping these files with the `unzip` command. The `unzip` command takes one argument, the name of the tile that you want to unzip.
#
#
# You can use tab completion (press the `tab` key after the first three letters) to fill in the names, including spaces. This will

# %%
sales_df = pd.read_csv('data/EXTR_RPSale.csv')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Seeing pink? Warnings are useful!
#
# Note the warning above: `DtypeWarning: Columns (1, 2) have mixed types.` Because we start with an index of zero, the columns that we're being warned about are actually the _second_ and _third_ columns, `sales_df['Major']` and `sales_df['Minor']`.

# %%
sales_df.T.head()
#0 for SalePrice: sometimes properties transfer/get inherited without a financial transaction
#for various circumstances, which we'd want to ignore
# Out:
#                  0           1           2           3           4        \
# ExciseTaxNbr     2687551     1235111     2704079     2584094     1056831
# Major             138860      664885      423943      403700      951120
# Minor                110          40          50         715         900
# DocumentDate  08/21/2014  07/09/1991  10/11/2014  01/04/2013  04/20/1989
# SalePrice         245000           0           0           0       85000
#
#                  5           6           7           8           9        \
# ExciseTaxNbr     1971467     1813750     1813750     1813750     1813750
# Major             605475       22209       22209       22209       22209
# Minor                 10        9001        9003        9007        9002
# DocumentDate  07/07/2003  04/25/2001  04/25/2001  04/25/2001  04/25/2001
# SalePrice              0     5755000     5755000     5755000     5755000
#
#                  ...         2014326     2014327     2014328     2014329  \
# ExciseTaxNbr     ...         2184061     2184061     2066401     2066401
# Major            ...          340470      340470       46470      276770
# Minor            ...              31          32         790         505
# DocumentDate     ...      01/26/2006  01/26/2006  08/16/2004  08/16/2004
# SalePrice        ...          868000      868000      206650      206650
#
#                  2014330     2014331     2014332     2014333     2014334  \
# ExciseTaxNbr     2616041     2213184     2899631     2200523     1541705
# Major             524980      401990      397170      375890      393190
# Minor               4024         175         835         225         455
# DocumentDate  06/13/2013  05/30/2006  11/02/2017  04/13/2006  04/24/1997
# SalePrice              0           0      445000           0      305000
#
#                  2014335
# ExciseTaxNbr     2492216
# Major             111300
# Minor                250
# DocumentDate  05/18/2011
# SalePrice              0
#
# [5 rows x 2014336 columns]

# %% [markdown]
# ### Data overload?
#
# That's a lot of columns. We're only interested in identifying the date, sale price, and square footage of each specific property. What can we do?

# %%
sales_df = sales_df[['Major', 'Minor', 'DocumentDate', 'SalePrice']]

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014336 entries, 0 to 2014335
# Data columns (total 4 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: int64(1), object(3)
# memory usage: 61.5+ MB

# %%
bldg_df = pd.read_csv('data/Residential Building.zip')
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
bldg_df.T
# Out:
#                                        0                            1       \
# Major                                    4300                         4610
# Minor                                     167                          399
# BldgNbr                                     1                            1
# NbrLivingUnits                              1                            1
# Address             15223   40TH AVE S  98188  4431   FERNCROFT RD   98040
# BuildingNumber                          15223                        4431
# Fraction
# DirectionPrefix
# StreetName          40TH                         FERNCROFT
# StreetType                             AVE                          RD
# DirectionSuffix                            S
# ZipCode                                 98188                        98040
# Stories                                     1                            2
# BldgGrade                                   6                            9
# BldgGradeVar                                0                            0
# SqFt1stFloor                              990                          980
# SqFtHalfFloor                               0                            0
# SqFt2ndFloor                                0                         1140
# SqFtUpperFloor                              0                            0
# SqFtUnfinFull                               0                            0
# SqFtUnfinHalf                               0                            0
# SqFtTotLiving                             990                         2950
# SqFtTotBasement                           990                          940
# SqFtFinBasement                             0                          830
# FinBasementGrade                            0                            9
# SqFtGarageBasement                          0                            0
# SqFtGarageAttached                          0                          480
# DaylightBasement                                                         Y
# SqFtOpenPorch                              80                            0
# SqFtEnclosedPorch                           0                            0
# SqFtDeck                                    0                          600
# HeatSystem                                  6                            5
# HeatSource                                  1                            2
# BrickStone                                  0                            0
# ViewUtilization                                                          N
# Bedrooms                                    2                            3
# BathHalfCount                               0                            1
# Bath3qtrCount                               0                            0
# BathFullCount                               1                            2
# FpSingleStory                               0                            0
# FpMultiStory                                0                            0
# FpFreestanding                              0                            2
# FpAdditional                                0                            0
# YrBuilt                                  1922                         1978
# YrRenovated                                 0                            0
# PcntComplete                                0                            0
# Obsolescence                                0                            0
# PcntNetCondition                            0                            0
# Condition                                   3                            4
# AddnlCost                                   0                            0
#
#                                          2                            3       \
# Major                                      4610                         4610
# Minor                                       503                          505
# BldgNbr                                       1                            1
# NbrLivingUnits                                1                            1
# Address             4516   FERNCROFT RD   98040  4538   FERNCROFT RD   98040
# BuildingNumber                            4516                         4538
# Fraction
# DirectionPrefix
# StreetName            FERNCROFT                    FERNCROFT
# StreetType                               RD                           RD
# DirectionSuffix
# ZipCode                                   98040                        98040
# Stories                                       2                            2
# BldgGrade                                     9                           11
# BldgGradeVar                                  0                            0
# SqFt1stFloor                               1916                         2250
# SqFtHalfFloor                                 0                            0
# SqFt2ndFloor                               1473                         1850
# SqFtUpperFloor                                0                            0
# SqFtUnfinFull                                 0                            0
# SqFtUnfinHalf                                 0                            0
# SqFtTotLiving                              3389                         4100
# SqFtTotBasement                               0                            0
# SqFtFinBasement                               0                            0
# FinBasementGrade                              0                            0
# SqFtGarageBasement                            0                            0
# SqFtGarageAttached                          552                          690
# DaylightBasement                              N                            N
# SqFtOpenPorch                               336                          120
# SqFtEnclosedPorch                           192                            0
# SqFtDeck                                   1028                          980
# HeatSystem                                    5                            5
# HeatSource                                    2                            2
# BrickStone                                    0                            0
# ViewUtilization                               N                            N
# Bedrooms                                      3                            5
# BathHalfCount                                 1                            1
# Bath3qtrCount                                 1                            0
# BathFullCount                                 1                            3
# FpSingleStory                                 0                            0
# FpMultiStory                                  2                            2
# FpFreestanding                                0                            0
# FpAdditional                                  0                            1
# YrBuilt                                    1970                         1989
# YrRenovated                                   0                            0
# PcntComplete                                  0                            0
# Obsolescence                                  0                            0
# PcntNetCondition                              0                            0
# Condition                                     4                            3
# AddnlCost                                     0                        20000
#
#                                        4                           5       \
# Major                                    4900                        4950
# Minor                                      56                          60
# BldgNbr                                     1                           1
# NbrLivingUnits                              1                           1
# Address             3015  SW 105TH ST   98146  2508   VASHON CT NE  98059
# BuildingNumber                          3015                        2508
# Fraction
# DirectionPrefix                            SW
# StreetName          105TH                       VASHON
# StreetType                             ST                          CT
# DirectionSuffix                                                        NE
# ZipCode                                 98146                       98059
# Stories                                     1                           1
# BldgGrade                                   7                           7
# BldgGradeVar                                0                           0
# SqFt1stFloor                             1040                        1340
# SqFtHalfFloor                               0                           0
# SqFt2ndFloor                                0                           0
# SqFtUpperFloor                              0                           0
# SqFtUnfinFull                               0                           0
# SqFtUnfinHalf                               0                           0
# SqFtTotLiving                            1570                        1340
# SqFtTotBasement                          1040                           0
# SqFtFinBasement                           530                           0
# FinBasementGrade                            7                           0
# SqFtGarageBasement                        430                           0
# SqFtGarageAttached                          0                         370
# DaylightBasement                                                        N
# SqFtOpenPorch                               0                           0
# SqFtEnclosedPorch                           0                           0
# SqFtDeck                                  100                           0
# HeatSystem                                  5                           5
# HeatSource                                  1                           2
# BrickStone                                  0                           0
# ViewUtilization                                                         N
# Bedrooms                                    3                           3
# BathHalfCount                               0                           1
# Bath3qtrCount                               0                           0
# BathFullCount                               1                           1
# FpSingleStory                               0                           1
# FpMultiStory                                1                           0
# FpFreestanding                              0                           1
# FpAdditional                                1                           0
# YrBuilt                                  1967                        1963
# YrRenovated                                 0                           0
# PcntComplete                                0                           0
# Obsolescence                                0                           0
# PcntNetCondition                            0                           0
# Condition                                   3                           3
# AddnlCost                                   0                           0
#
#                                         6                           7       \
# Major                                     5030                        5030
# Minor                                      300                         350
# BldgNbr                                      1                           1
# NbrLivingUnits                               1                           1
# Address             26115   201ST PL SE  98042  20101  SE 260TH PL   98042
# BuildingNumber                           26115                       20101
# Fraction
# DirectionPrefix                                                         SE
# StreetName           201ST                       260TH
# StreetType                              PL                          PL
# DirectionSuffix                             SE
# ZipCode                                  98042                       98042
# Stories                                      2                           2
# BldgGrade                                    8                           8
# BldgGradeVar                                 0                           0
# SqFt1stFloor                              1290                        1340
# SqFtHalfFloor                                0                           0
# SqFt2ndFloor                              1230                        1660
# SqFtUpperFloor                               0                           0
# SqFtUnfinFull                                0                           0
# SqFtUnfinHalf                                0                           0
# SqFtTotLiving                             2520                        3000
# SqFtTotBasement                              0                           0
# SqFtFinBasement                              0                           0
# FinBasementGrade                             0                           0
# SqFtGarageBasement                           0                           0
# SqFtGarageAttached                         700                         720
# DaylightBasement                             N                           N
# SqFtOpenPorch                                0                         130
# SqFtEnclosedPorch                            0                           0
# SqFtDeck                                   100                           0
# HeatSystem                                   5                           5
# HeatSource                                   2                           2
# BrickStone                                   0                           0
# ViewUtilization                              N                           N
# Bedrooms                                     5                           4
# BathHalfCount                                0                           0
# Bath3qtrCount                                0                           0
# BathFullCount                                3                           3
# FpSingleStory                                1                           1
# FpMultiStory                                 0                           0
# FpFreestanding                               0                           0
# FpAdditional                                 0                           0
# YrBuilt                                   2004                        2004
# YrRenovated                                  0                           0
# PcntComplete                                 0                           0
# Obsolescence                                 0                           0
# PcntNetCondition                             0                           0
# Condition                                    3                           3
# AddnlCost                                 6000                        6000
#
#                                        8                          9       \
# Major                                    5100                       5200
# Minor                                     160                         21
# BldgNbr                                     1                          1
# NbrLivingUnits                              1                          1
# Address             2115  SW 305TH ST   98023        1212 A  6TH AVE N
# BuildingNumber                          2115                       1212
# Fraction                                                             A
# DirectionPrefix                            SW
# StreetName          305TH                      6TH
# StreetType                             ST                         AVE
# DirectionSuffix                                                       N
# ZipCode                                 98023                        NaN
# Stories                                     1                          2
# BldgGrade                                   7                          7
# BldgGradeVar                                0                          0
# SqFt1stFloor                             1220                        420
# SqFtHalfFloor                               0                          0
# SqFt2ndFloor                                0                        420
# SqFtUpperFloor                              0                          0
# SqFtUnfinFull                               0                          0
# SqFtUnfinHalf                               0                          0
# SqFtTotLiving                            2140                        920
# SqFtTotBasement                          1140                        310
# SqFtFinBasement                           920                         80
# FinBasementGrade                            7                          7
# SqFtGarageBasement                        220                        230
# SqFtGarageAttached                        200                          0
# DaylightBasement                            Y
# SqFtOpenPorch                               0                          0
# SqFtEnclosedPorch                           0                          0
# SqFtDeck                                  100                          0
# HeatSystem                                  5                          5
# HeatSource                                  2                          2
# BrickStone                                  0                          0
# ViewUtilization
# Bedrooms                                    3                          3
# BathHalfCount                               0                          1
# Bath3qtrCount                               1                          0
# BathFullCount                               2                          2
# FpSingleStory                               1                          0
# FpMultiStory                                0                          0
# FpFreestanding                              0                          0
# FpAdditional                                0                          0
# YrBuilt                                  1978                       2008
# YrRenovated                                 0                          0
# PcntComplete                                0                          0
# Obsolescence                                0                          0
# PcntNetCondition                            0                          0
# Condition                                   4                          3
# AddnlCost                                   0                          0
#
#                               ...                                 511402  \
# Major                         ...                                 395940
# Minor                         ...                                    210
# BldgNbr                       ...                                      1
# NbrLivingUnits                ...                                      1
# Address                       ...               4331   14TH AVE S  98108
# BuildingNumber                ...                                  4331
# Fraction                      ...
# DirectionPrefix               ...
# StreetName                    ...              14TH
# StreetType                    ...                                 AVE
# DirectionSuffix               ...                                     S
# ZipCode                       ...                                  98108
# Stories                       ...                                      1
# BldgGrade                     ...                                      7
# BldgGradeVar                  ...                                      0
# SqFt1stFloor                  ...                                   1020
# SqFtHalfFloor                 ...                                      0
# SqFt2ndFloor                  ...                                      0
# SqFtUpperFloor                ...                                      0
# SqFtUnfinFull                 ...                                      0
# SqFtUnfinHalf                 ...                                      0
# SqFtTotLiving                 ...                                   1020
# SqFtTotBasement               ...                                   1020
# SqFtFinBasement               ...                                      0
# FinBasementGrade              ...                                      0
# SqFtGarageBasement            ...                                      0
# SqFtGarageAttached            ...                                      0
# DaylightBasement              ...
# SqFtOpenPorch                 ...                                      0
# SqFtEnclosedPorch             ...                                      0
# SqFtDeck                      ...                                      0
# HeatSystem                    ...                                      5
# HeatSource                    ...                                      1
# BrickStone                    ...                                      0
# ViewUtilization               ...
# Bedrooms                      ...                                      3
# BathHalfCount                 ...                                      0
# Bath3qtrCount                 ...                                      1
# BathFullCount                 ...                                      1
# FpSingleStory                 ...                                      0
# FpMultiStory                  ...                                      1
# FpFreestanding                ...                                      0
# FpAdditional                  ...                                      1
# YrBuilt                       ...                                   1942
# YrRenovated                   ...                                      0
# PcntComplete                  ...                                      0
# Obsolescence                  ...                                      0
# PcntNetCondition              ...                                      0
# Condition                     ...                                      3
# AddnlCost                     ...                                      0
#
#                                        511403                     511404  \
# Major                                  395940                     395940
# Minor                                     215                        350
# BldgNbr                                     1                          1
# NbrLivingUnits                              1                          1
# Address              4327   14TH AVE S  98108   4155   14TH AVE S  98108
# BuildingNumber                          4327                       4155
# Fraction
# DirectionPrefix
# StreetName          14TH                       14TH
# StreetType                             AVE                        AVE
# DirectionSuffix                            S                          S
# ZipCode                                 98108                      98108
# Stories                                     1                          1
# BldgGrade                                   7                          7
# BldgGradeVar                                0                          0
# SqFt1stFloor                             1110                        970
# SqFtHalfFloor                               0                          0
# SqFt2ndFloor                                0                          0
# SqFtUpperFloor                              0                          0
# SqFtUnfinFull                               0                          0
# SqFtUnfinHalf                               0                          0
# SqFtTotLiving                            1380                        970
# SqFtTotBasement                          1110                        430
# SqFtFinBasement                           270                          0
# FinBasementGrade                            5                          0
# SqFtGarageBasement                        210                          0
# SqFtGarageAttached                          0                          0
# DaylightBasement                            N
# SqFtOpenPorch                              40                          0
# SqFtEnclosedPorch                           0                          0
# SqFtDeck                                    0                          0
# HeatSystem                                  5                          5
# HeatSource                                  1                          1
# BrickStone                                100                          0
# ViewUtilization                             N
# Bedrooms                                    3                          2
# BathHalfCount                               1                          0
# Bath3qtrCount                               0                          0
# BathFullCount                               1                          1
# FpSingleStory                               1                          1
# FpMultiStory                                0                          0
# FpFreestanding                              0                          0
# FpAdditional                                0                          0
# YrBuilt                                  1952                       1942
# YrRenovated                                 0                          0
# PcntComplete                                0                          0
# Obsolescence                                0                          0
# PcntNetCondition                            0                          0
# Condition                                   3                          4
# AddnlCost                                   0                          0
#
#                                        511405                     511406  \
# Major                                  395940                     395940
# Minor                                     455                        505
# BldgNbr                                     1                          1
# NbrLivingUnits                              1                          1
# Address              4158   13TH AVE S  98108   4127   13TH AVE S  98108
# BuildingNumber                          4158                       4127
# Fraction
# DirectionPrefix
# StreetName          13TH                       13TH
# StreetType                             AVE                        AVE
# DirectionSuffix                            S                          S
# ZipCode                                 98108                      98108
# Stories                                     1                          1
# BldgGrade                                   6                          7
# BldgGradeVar                                0                          0
# SqFt1stFloor                              910                       1120
# SqFtHalfFloor                               0                          0
# SqFt2ndFloor                                0                          0
# SqFtUpperFloor                              0                          0
# SqFtUnfinFull                               0                          0
# SqFtUnfinHalf                               0                          0
# SqFtTotLiving                             910                       1940
# SqFtTotBasement                           910                       1120
# SqFtFinBasement                             0                        820
# FinBasementGrade                            0                          5
# SqFtGarageBasement                        240                        300
# SqFtGarageAttached                          0                          0
# DaylightBasement                            N
# SqFtOpenPorch                              60                          0
# SqFtEnclosedPorch                           0                          0
# SqFtDeck                                  110                        350
# HeatSystem                                  5                          5
# HeatSource                                  2                          1
# BrickStone                                  0                        100
# ViewUtilization                             N
# Bedrooms                                    2                          3
# BathHalfCount                               0                          0
# Bath3qtrCount                               0                          1
# BathFullCount                               1                          1
# FpSingleStory                               1                          1
# FpMultiStory                                0                          0
# FpFreestanding                              0                          0
# FpAdditional                                0                          0
# YrBuilt                                  1940                       1940
# YrRenovated                                 0                          0
# PcntComplete                                0                          0
# Obsolescence                                0                          0
# PcntNetCondition                            0                          0
# Condition                                   3                          3
# AddnlCost                                   0                          0
#
#                                        511407                     511408  \
# Major                                  395940                     395940
# Minor                                     577                        590
# BldgNbr                                     1                          1
# NbrLivingUnits                              1                          1
# Address              4158   12TH AVE S  98108   4351   13TH AVE S  98108
# BuildingNumber                          4158                       4351
# Fraction
# DirectionPrefix
# StreetName          12TH                       13TH
# StreetType                             AVE                        AVE
# DirectionSuffix                            S                          S
# ZipCode                                 98108                      98108
# Stories                                     1                          1
# BldgGrade                                   7                          7
# BldgGradeVar                                0                          0
# SqFt1stFloor                              970                       1550
# SqFtHalfFloor                               0                          0
# SqFt2ndFloor                                0                          0
# SqFtUpperFloor                              0                          0
# SqFtUnfinFull                               0                          0
# SqFtUnfinHalf                               0                          0
# SqFtTotLiving                            1470                       2400
# SqFtTotBasement                           970                       1480
# SqFtFinBasement                           500                        850
# FinBasementGrade                            6                          6
# SqFtGarageBasement                          0                        500
# SqFtGarageAttached                          0                          0
# DaylightBasement                            N                          N
# SqFtOpenPorch                               0                        260
# SqFtEnclosedPorch                           0                          0
# SqFtDeck                                    0                          0
# HeatSystem                                  5                          7
# HeatSource                                  1                          3
# BrickStone                                  0                          0
# ViewUtilization                             N                          N
# Bedrooms                                    3                          4
# BathHalfCount                               0                          0
# Bath3qtrCount                               0                          1
# BathFullCount                               1                          1
# FpSingleStory                               1                          0
# FpMultiStory                                0                          1
# FpFreestanding                              0                          0
# FpAdditional                                0                          1
# YrBuilt                                  1940                       1966
# YrRenovated                                 0                          0
# PcntComplete                                0                          0
# Obsolescence                                0                          0
# PcntNetCondition                            0                          0
# Condition                                   3                          3
# AddnlCost                                   0                          0
#
#                                        511409                     511410  \
# Major                                  395940                     395940
# Minor                                     690                       1120
# BldgNbr                                     1                          1
# NbrLivingUnits                              1                          1
# Address              4314   12TH AVE S  98108   4337   12TH AVE S  98108
# BuildingNumber                          4314                       4337
# Fraction
# DirectionPrefix
# StreetName          12TH                       12TH
# StreetType                             AVE                        AVE
# DirectionSuffix                            S                          S
# ZipCode                                 98108                      98108
# Stories                                     1                          1
# BldgGrade                                   7                          7
# BldgGradeVar                                0                          0
# SqFt1stFloor                              840                       1030
# SqFtHalfFloor                               0                          0
# SqFt2ndFloor                                0                          0
# SqFtUpperFloor                              0                          0
# SqFtUnfinFull                               0                          0
# SqFtUnfinHalf                               0                          0
# SqFtTotLiving                            1460                       1490
# SqFtTotBasement                           840                       1030
# SqFtFinBasement                           620                        460
# FinBasementGrade                            6                          6
# SqFtGarageBasement                        220                          0
# SqFtGarageAttached                          0                          0
# DaylightBasement                            N
# SqFtOpenPorch                              40                          0
# SqFtEnclosedPorch                           0                          0
# SqFtDeck                                  140                          0
# HeatSystem                                  5                          5
# HeatSource                                  1                          1
# BrickStone                                  0                        100
# ViewUtilization                             N
# Bedrooms                                    2                          3
# BathHalfCount                               0                          0
# Bath3qtrCount                               0                          0
# BathFullCount                               1                          1
# FpSingleStory                               0                          1
# FpMultiStory                                1                          0
# FpFreestanding                              0                          0
# FpAdditional                                1                          1
# YrBuilt                                  1944                       1941
# YrRenovated                                 0                          0
# PcntComplete                                0                          0
# Obsolescence                                0                          0
# PcntNetCondition                            0                          0
# Condition                                   5                          3
# AddnlCost                                   0                          0
#
#                                        511411
# Major                                  395940
# Minor                                    1405
# BldgNbr                                     1
# NbrLivingUnits                              1
# Address             4405   POWELL PL S  98108
# BuildingNumber                          4405
# Fraction
# DirectionPrefix
# StreetName          POWELL
# StreetType                             PL
# DirectionSuffix                            S
# ZipCode                                 98108
# Stories                                     1
# BldgGrade                                   8
# BldgGradeVar                                0
# SqFt1stFloor                             1230
# SqFtHalfFloor                               0
# SqFt2ndFloor                                0
# SqFtUpperFloor                              0
# SqFtUnfinFull                               0
# SqFtUnfinHalf                               0
# SqFtTotLiving                            1930
# SqFtTotBasement                          1230
# SqFtFinBasement                           700
# FinBasementGrade                            7
# SqFtGarageBasement                        520
# SqFtGarageAttached                          0
# DaylightBasement                            Y
# SqFtOpenPorch                               0
# SqFtEnclosedPorch                           0
# SqFtDeck                                  250
# HeatSystem                                  5
# HeatSource                                  2
# BrickStone                                100
# ViewUtilization                             N
# Bedrooms                                    3
# BathHalfCount                               0
# Bath3qtrCount                               2
# BathFullCount                               1
# FpSingleStory                               0
# FpMultiStory                                0
# FpFreestanding                              0
# FpAdditional                                0
# YrBuilt                                  1993
# YrRenovated                                 0
# PcntComplete                                0
# Obsolescence                                0
# PcntNetCondition                            0
# Condition                                   4
# AddnlCost                                   0
#
# [50 rows x 511412 columns]

# %% [markdown]
# ### Another warning! Which column has index 11?

# %%
bldg_df.columns[11]
# Out:
# 'ZipCode'

# %% [markdown]
# `ZipCode` seems like a potentially useful column. We'll need it to determine which house sales took place in Seattle.

# %%
bldg_df.head().T
# Out:
#                                             0                            1  \
# Major                                    4300                         4610
# Minor                                     167                          399
# BldgNbr                                     1                            1
# NbrLivingUnits                              1                            1
# Address             15223   40TH AVE S  98188  4431   FERNCROFT RD   98040
# BuildingNumber                          15223                        4431
# Fraction
# DirectionPrefix
# StreetName          40TH                         FERNCROFT
# StreetType                             AVE                          RD
# DirectionSuffix                            S
# ZipCode                                 98188                        98040
# Stories                                     1                            2
# BldgGrade                                   6                            9
# BldgGradeVar                                0                            0
# SqFt1stFloor                              990                          980
# SqFtHalfFloor                               0                            0
# SqFt2ndFloor                                0                         1140
# SqFtUpperFloor                              0                            0
# SqFtUnfinFull                               0                            0
# SqFtUnfinHalf                               0                            0
# SqFtTotLiving                             990                         2950
# SqFtTotBasement                           990                          940
# SqFtFinBasement                             0                          830
# FinBasementGrade                            0                            9
# SqFtGarageBasement                          0                            0
# SqFtGarageAttached                          0                          480
# DaylightBasement                                                         Y
# SqFtOpenPorch                              80                            0
# SqFtEnclosedPorch                           0                            0
# SqFtDeck                                    0                          600
# HeatSystem                                  6                            5
# HeatSource                                  1                            2
# BrickStone                                  0                            0
# ViewUtilization                                                          N
# Bedrooms                                    2                            3
# BathHalfCount                               0                            1
# Bath3qtrCount                               0                            0
# BathFullCount                               1                            2
# FpSingleStory                               0                            0
# FpMultiStory                                0                            0
# FpFreestanding                              0                            2
# FpAdditional                                0                            0
# YrBuilt                                  1922                         1978
# YrRenovated                                 0                            0
# PcntComplete                                0                            0
# Obsolescence                                0                            0
# PcntNetCondition                            0                            0
# Condition                                   3                            4
# AddnlCost                                   0                            0
#
#                                               2                            3  \
# Major                                      4610                         4610
# Minor                                       503                          505
# BldgNbr                                       1                            1
# NbrLivingUnits                                1                            1
# Address             4516   FERNCROFT RD   98040  4538   FERNCROFT RD   98040
# BuildingNumber                            4516                         4538
# Fraction
# DirectionPrefix
# StreetName            FERNCROFT                    FERNCROFT
# StreetType                               RD                           RD
# DirectionSuffix
# ZipCode                                   98040                        98040
# Stories                                       2                            2
# BldgGrade                                     9                           11
# BldgGradeVar                                  0                            0
# SqFt1stFloor                               1916                         2250
# SqFtHalfFloor                                 0                            0
# SqFt2ndFloor                               1473                         1850
# SqFtUpperFloor                                0                            0
# SqFtUnfinFull                                 0                            0
# SqFtUnfinHalf                                 0                            0
# SqFtTotLiving                              3389                         4100
# SqFtTotBasement                               0                            0
# SqFtFinBasement                               0                            0
# FinBasementGrade                              0                            0
# SqFtGarageBasement                            0                            0
# SqFtGarageAttached                          552                          690
# DaylightBasement                              N                            N
# SqFtOpenPorch                               336                          120
# SqFtEnclosedPorch                           192                            0
# SqFtDeck                                   1028                          980
# HeatSystem                                    5                            5
# HeatSource                                    2                            2
# BrickStone                                    0                            0
# ViewUtilization                               N                            N
# Bedrooms                                      3                            5
# BathHalfCount                                 1                            1
# Bath3qtrCount                                 1                            0
# BathFullCount                                 1                            3
# FpSingleStory                                 0                            0
# FpMultiStory                                  2                            2
# FpFreestanding                                0                            0
# FpAdditional                                  0                            1
# YrBuilt                                    1970                         1989
# YrRenovated                                   0                            0
# PcntComplete                                  0                            0
# Obsolescence                                  0                            0
# PcntNetCondition                              0                            0
# Condition                                     4                            3
# AddnlCost                                     0                        20000
#
#                                             4
# Major                                    4900
# Minor                                      56
# BldgNbr                                     1
# NbrLivingUnits                              1
# Address             3015  SW 105TH ST   98146
# BuildingNumber                          3015
# Fraction
# DirectionPrefix                            SW
# StreetName          105TH
# StreetType                             ST
# DirectionSuffix
# ZipCode                                 98146
# Stories                                     1
# BldgGrade                                   7
# BldgGradeVar                                0
# SqFt1stFloor                             1040
# SqFtHalfFloor                               0
# SqFt2ndFloor                                0
# SqFtUpperFloor                              0
# SqFtUnfinFull                               0
# SqFtUnfinHalf                               0
# SqFtTotLiving                            1570
# SqFtTotBasement                          1040
# SqFtFinBasement                           530
# FinBasementGrade                            7
# SqFtGarageBasement                        430
# SqFtGarageAttached                          0
# DaylightBasement
# SqFtOpenPorch                               0
# SqFtEnclosedPorch                           0
# SqFtDeck                                  100
# HeatSystem                                  5
# HeatSource                                  1
# BrickStone                                  0
# ViewUtilization
# Bedrooms                                    3
# BathHalfCount                               0
# Bath3qtrCount                               0
# BathFullCount                               1
# FpSingleStory                               0
# FpMultiStory                                1
# FpFreestanding                              0
# FpAdditional                                1
# YrBuilt                                  1967
# YrRenovated                                 0
# PcntComplete                                0
# Obsolescence                                0
# PcntNetCondition                            0
# Condition                                   3
# AddnlCost                                   0

# %% [markdown]
# ### So many features!
#
# As data scientists, we should be _very_ cautious about discarding potentially useful data. But, today, we're interested in _only_ the total square footage of each property. What can we do?

# %%
bldg_df = bldg_df[['Major', 'Minor', 'SqFtTotLiving', 'ZipCode']]

# %%
bldg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511412 entries, 0 to 511411
# Data columns (total 4 columns):
# Major            511412 non-null int64
# Minor            511412 non-null int64
# SqFtTotLiving    511412 non-null int64
# ZipCode          468372 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.6+ MB

# %%
sales_data = pd.merge(sales_df, bldg_df, on=['Major', 'Minor'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-764b2d8a2609> in <module>
# ----> 1 sales_data = pd.merge(sales_df, bldg_df, on=['Major', 'Minor'])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     553         # validate the merge keys dtypes. We may need to coerce
#     554         # to avoid incompat dtypes
# --> 555         self._maybe_coerce_merge_keys()
#     556
#     557         # If argument passed to validate,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#     984             elif (not is_numeric_dtype(lk)
#     985                     and (is_numeric_dtype(rk) and not is_bool_dtype(rk))):
# --> 986                 raise ValueError(msg)
#     987             elif is_datetimelike(lk) and not is_datetimelike(rk):
#     988                 raise ValueError(msg)
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %% [markdown]
# ### Error!
#
# Why are we seeing an error when we try to join the dataframes?
#
# <table>
#     <tr>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013160 entries, 0 to 2013159
# Data columns (total 4 columns):
# Major           object
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: int64(1), object(3)
# memory usage: 61.4+ MB</pre></td>
#         <td style="text-align:left"><pre>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 511359 entries, 0 to 511358
# Data columns (total 4 columns):
# Major            511359 non-null int64
# Minor            511359 non-null int64
# SqFtTotLiving    511359 non-null int64
# ZipCode          468345 non-null object
# dtypes: int64(3), object(1)
# memory usage: 15.6+ MB
# </pre></td>
#     </tr>
# </table>
#
# Review the error message in light of the above:
#
# * `ValueError: You are trying to merge on object and int64 columns.`

# %%
sales_df['Major'] = pd.to_numeric(sales_df['Major'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "      "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-a99a999cbad4> in <module>
# ----> 1 sales_df['Major'] = pd.to_numeric(sales_df['Major'])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "      " at position 935519

# %% [markdown]
# ### Error!
#
# Note the useful error message above:
#
# `ValueError: Unable to parse string "      " at position 936643`
#
# In this case, we want to treat non-numeric values as missing values. Let's see if there's a way to change how the `pd.to_numeric` function handles errors.

# %%
# The single question mark means "show me the docstring"
pd.to_numeric?

# %% [markdown]
# Here's the part that we're looking for:
# ```
# errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#     - If 'raise', then invalid parsing will raise an exception
#     - If 'coerce', then invalid parsing will be set as NaN
#     - If 'ignore', then invalid parsing will return the input
# ```
#
# Let's try setting the `errors` parameter to `'coerce'`.

# %%
sales_df['Major'] = pd.to_numeric(sales_df['Major'], errors='coerce')

# %% [markdown]
# Did it work?

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014336 entries, 0 to 2014335
# Data columns (total 4 columns):
# Major           float64
# Minor           object
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 61.5+ MB

# %% [markdown]
# It worked! Let's do the same thing with the `Minor` parcel number.

# %%
sales_df['Minor'] = pd.to_numeric(sales_df['Minor'], errors='coerce')

# %%
sales_df.info()
#float64 more usable int64 when there are NaNs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014336 entries, 0 to 2014335
# Data columns (total 4 columns):
# Major           float64
# Minor           float64
# DocumentDate    object
# SalePrice       int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 61.5+ MB

# %% [markdown]
# Now, let's try our join again.

# %%
sales_data = pd.merge(sales_df, bldg_df, on=['Major', 'Minor'])

# %%
sales_data.head()
# Out:
#       Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 0  138860.0  110.0   08/21/2014     245000           1490   98002
# 1  138860.0  110.0   06/12/1989     109300           1490   98002
# 2  138860.0  110.0   01/16/2005      14684           1490   98002
# 3  138860.0  110.0   06/08/2005          0           1490   98002
# 4  423943.0   50.0   10/11/2014          0            960   98092

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1437522 entries, 0 to 1437521
# Data columns (total 6 columns):
# Major            1437522 non-null float64
# Minor            1437522 non-null float64
# DocumentDate     1437522 non-null object
# SalePrice        1437522 non-null int64
# SqFtTotLiving    1437522 non-null int64
# ZipCode          1322148 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 76.8+ MB

# %% [markdown]
# We can see right away that we're missing zip codes for many of the sales transactions. (1321536 non-null entries for ZipCode is fewer than the 1436772 entries in the dataframe.)

# %%
sales_data.loc[sales_data['ZipCode'].isna()].head()
# Out:
#         Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 99   858140.0  376.0   05/22/2012          0            900     NaN
# 100  858140.0  376.0   11/28/2017          0            900     NaN
# 152  720319.0  520.0   11/20/2013     699950           2840     NaN
# 153  720319.0  520.0   09/16/2013          0           2840     NaN
# 163  894677.0  240.0   12/21/2016     818161           2450     NaN

# %% [markdown]
# Because we are interested in finding houses in Seattle zip codes, we will need to drop the rows with missing zip codes.

# %%
sales_data = sales_data.loc[~sales_data['ZipCode'].isna(), :]
#Boolean mask: squiggle flips 1's and 0's
#equation above is saying:
#keep sales_data dataframe where ROWS = ZipCode is NOT NaN, ALL COLUMNS

sales_data.head()
# Out:
#       Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 0  138860.0  110.0   08/21/2014     245000           1490   98002
# 1  138860.0  110.0   06/12/1989     109300           1490   98002
# 2  138860.0  110.0   01/16/2005      14684           1490   98002
# 3  138860.0  110.0   06/08/2005          0           1490   98002
# 4  423943.0   50.0   10/11/2014          0            960   98092

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1322148 entries, 0 to 1437521
# Data columns (total 6 columns):
# Major            1322148 non-null float64
# Minor            1322148 non-null float64
# DocumentDate     1322148 non-null object
# SalePrice        1322148 non-null int64
# SqFtTotLiving    1322148 non-null int64
# ZipCode          1322148 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 70.6+ MB

# %% [markdown]
# # Your turn: Data Cleaning with Pandas

# %% [markdown]
# ### 1. Investigate and drop rows with invalid values in the SalePrice and SqFtTotLiving columns.
#
# Use multiple notebook cells to accomplish this! Press `[esc]` then `B` to create a new cell below the current cell. Press `[return]` to start typing in the new cell.

# %%
sales_data = sales_data.loc[sales_data['SalePrice'] > 0]

# %%
sales_data.head()
# Out:
#       Major  Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode
# 0  138860.0  110.0   08/21/2014     245000           1490   98002
# 1  138860.0  110.0   06/12/1989     109300           1490   98002
# 2  138860.0  110.0   01/16/2005      14684           1490   98002
# 6  423943.0   50.0   07/15/1999      96000            960   98092
# 7  423943.0   50.0   01/08/2001     127500            960   98092

# %%
sales_data = sales_data.loc[sales_data['SqFtTotLiving'] >= 100]

# %%
sales_data['SqFtTotLiving'].min()
# Out:
# 100

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 867397 entries, 0 to 1437520
# Data columns (total 6 columns):
# Major            867397 non-null float64
# Minor            867397 non-null float64
# DocumentDate     867397 non-null object
# SalePrice        867397 non-null int64
# SqFtTotLiving    867397 non-null int64
# ZipCode          867397 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 46.3+ MB

# %% [markdown]
# ### 2. Investigate and handle non-numeric ZipCode values
#
# Can you find a way to shorten ZIP+4 codes to the first five digits?
#
# What's the right thing to do with missing values?

# %%
# Read the error message and decide how to fix it.
# Note: using errors='coerce' is the *wrong* choice in this case.
def is_integer(x):
    try:
        _ = int(x)
    except ValueError:
        return False
    return True

sales_data.loc[sales_data['ZipCode'].apply(is_integer) == False, 'ZipCode']
# Out:
# 10168      98042-3001
# 10169      98042-3001
# 10170      98042-3001
# 10171      98042-3001
# 16528      98199-3014
# 16529      98199-3014
# 16530      98199-3014
# 40183      98031-3173
# 43081      98042-3001
# 43082      98042-3001
# 53691      98033-4917
# 53692      98033-4917
# 53693      98033-4917
# 53694      98033-4917
# 53695      98033-4917
# 87152      98058-9018
# 87153      98058-9018
# 93627      98136-1728
# 93628      98136-1728
# 93629      98136-1728
# 93630      98136-1728
# 146181     98058-7983
# 146183     98058-7983
# 151057     98074-6315
# 151058     98074-6315
# 151062     98074-6315
# 163641     98052-1963
# 242179     98023-2712
# 242181     98023-2712
# 251279     98028-4768
#               ...
# 1190128    98042-3001
# 1198332    98074-4092
# 1252275    98042-3001
# 1252667    98146-3008
# 1252668    98146-3008
# 1259514    98059-7120
# 1268080    98042-3001
# 1268081    98042-3001
# 1300491            WA
# 1300492            WA
# 1310974    98042-8215
# 1310975    98042-8215
# 1310976    98042-8215
# 1310977    98042-8215
# 1317353    98028-4625
# 1317354    98028-4625
# 1317355    98028-4625
# 1321985    98028-8908
# 1335540    98075-9565
# 1347555    98042-4811
# 1347556    98042-4811
# 1376251    98042-3001
# 1385843    98023-7841
# 1391669    98045-9504
# 1401743    98074-4122
# 1405212    98028-8533
# 1407848    98028-6100
# 1410052    98042-3001
# 1410053    98042-3001
# 1411342            WA
# Name: ZipCode, Length: 174, dtype: object

# %%
integer_zip_df = sales_data.loc[sales_data['ZipCode'].apply(is_integer) == True]
not_integer_zip_df = sales_data.loc[sales_data['ZipCode'].apply(is_integer) == False]

# %%
not_integer_zip_df['ZipCode'].apply(lambda x: x[:5]).values
# Out:
# array(['98042', '98042', '98042', '98042', '98199', '98199', '98199',
#        '98031', '98042', '98042', '98033', '98033', '98033', '98033',
#        '98033', '98058', '98058', '98136', '98136', '98136', '98136',
#        '98058', '98058', '98074', '98074', '98074', '98052', '98023',
#        '98023', '98028', '98028', '98028', '98028', '98038', '98038',
#        '98038', '98177', '98177', 'A', 'A', '98042', '98042', '98074',
#        '98074', '98074', '98074', '98074', '98074', '98074', '98059',
#        '98034', '98034', 'B', ' ', ' ', ' ', '98023', '98023', '98028',
#        '98028', '98074', '98074', '98006', '98053', '98074', '98074',
#        '98008', '98008', '98075', '98075', '98075', '98075', '98075',
#        '98055', '98055', '98042', '98042', '98075', '98118', '98118',
#        '98118', '98074', '98074', ' ', ' ', '98028', '98198', '98198',
#        '98198', '98198', '98075', '98075', '98075', '98075', '98028',
#        '98028', '98028', '98107', '98107', '98107', '98074', '98074',
#        '98028', '98042', '98042', '98074', '98074', '98033', '98033',
#        '98075', '98075', '98118', '98118', '98029', '98029', '98029',
#        '98042', '98042', '98042', '98042', '98028', '98075', '98028',
#        '98028', '98028', '98042', '98075', '98075', '98075', '98074',
#        '98042', '98042', '98042', '98011', '98011', '98059', '98059',
#        '98059', '98075', '98058', '98058', '98074', '98042', '98042',
#        '98042', '98074', '98042', '98146', '98146', '98059', '98042',
#        '98042', 'WA', 'WA', '98042', '98042', '98042', '98042', '98028',
#        '98028', '98028', '98028', '98075', '98042', '98042', '98042',
#        '98023', '98045', '98074', '98028', '98028', '98042', '98042',
#        'WA'], dtype=object)

# %%
sales_data.loc[sales_data['ZipCode'].apply(is_integer) == False, 'ZipCode'] = not_integer_zip_df['ZipCode'].apply(lambda x: x[:5]).values

# %%
sales_data = sales_data.loc[sales_data['ZipCode'].apply(is_integer) == True]

# %%
sales_data = sales_data.reset_index(drop=True)
sales_data
# Out:
#            Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode  \
# 0       138860.0   110.0   08/21/2014     245000           1490   98002
# 1       138860.0   110.0   06/12/1989     109300           1490   98002
# 2       138860.0   110.0   01/16/2005      14684           1490   98002
# 3       423943.0    50.0   07/15/1999      96000            960   98092
# 4       423943.0    50.0   01/08/2001     127500            960   98092
# 5       403700.0   715.0   07/03/2013     464500           1780   98008
# 6       403700.0   715.0   02/21/2013     357000           1780   98008
# 7       403700.0   715.0   10/13/1995     142000           1780   98008
# 8       403700.0   715.0   02/22/2007     528000           1780   98008
# 9        98400.0   380.0   03/23/1994     139950           2050   98058
# 10       98400.0   380.0   03/29/2017     439500           2050   98058
# 11      330395.0  1610.0   06/07/2012     335000           2210   98038
# 12      330395.0  1610.0   08/26/2013     369900           2210   98038
# 13      330395.0  1610.0   06/27/1994     192950           2210   98038
# 14      330395.0  1610.0   08/22/2013     369900           2210   98038
# 15      330395.0  1610.0   11/10/1993     107500           2210   98038
# 16      675260.0   940.0   03/06/1998     209950           2040   98031
# 17      675260.0   940.0   08/01/1995     191950           2040   98031
# 18      675260.0   940.0   09/13/2004     289950           2040   98031
# 19      795508.0   170.0   04/09/2001     174000            980   98058
# 20      795508.0   170.0   10/31/1996     135000            980   98058
# 21      795508.0   170.0   04/30/2004     210000            980   98058
# 22      795508.0   170.0   12/21/2012     148000            980   98058
# 23      638580.0   110.0   07/14/2015     190000           2130   98188
# 24      638580.0   110.0   12/21/2015     338000           2130   98188
# 25      252206.0  9011.0   02/21/1997     300000           2530   98051
# 26      252206.0  9011.0   11/28/2000     390000           2530   98051
# 27      321165.0    50.0   05/10/2004    2100000           1800   98001
# 28      321165.0    50.0   10/24/2013     215000           1800   98001
# 29      321165.0    50.0   09/20/2004     270000           1800   98001
# ...          ...     ...          ...        ...            ...     ...
# 867356  928170.0     5.0   12/11/1986      89950           1630   98116
# 867357  783280.0    60.0   08/21/1986      67500           1200   98146
# 867358  809260.0    80.0   08/20/2001     145000           1170   98042
# 867359  344800.0  1500.0   07/12/1996     174000            680   98125
# 867360  177421.0   370.0   06/24/1993     233000           2930   98077
# 867361  278731.0   900.0   10/18/1982      78000           1590   98031
# 867362   12605.0  9008.0   10/01/1993     110000            790   98072
# 867363   42506.0  9158.0   03/07/1988      35000           1920   98053
# 867364  955020.0  4120.0   03/24/1994     156500           1370   98105
# 867365  220750.0   450.0   05/19/1993     199000           1430   98102
# 867366  546878.0   130.0   03/23/2005     309900           1940   98042
# 867367  251700.0   900.0   07/05/2005     272195           1920   98042
# 867368  881990.0   515.0   09/25/1985      63500            870   98105
# 867369  222505.0  9207.0   10/09/1995     246500           2570   98005
# 867370  222505.0  9207.0   10/09/1995     246500           1070   98005
# 867371  541860.0    20.0   07/23/2002     450000           2890   98115
# 867372  172606.0  9181.0   07/26/1983      87950           2320   98077
# 867373  293500.0   100.0   01/23/1987      66850           1190   98001
# 867374   80900.0  1440.0   10/19/1988     147000           1730   98109
# 867375  247338.0   310.0   07/27/1987      83000           1870   98058
# 867376   11410.0   629.0   01/26/1998     171000            730   98028
# 867377  568000.0   570.0   01/09/2013     400000           2120   98108
# 867378  944230.0    10.0   10/01/2001     280000           2530   98177
# 867379  797990.0   510.0   09/27/1985      62000           1730   98155
# 867380   42007.0  9047.0   03/09/1988      86000           1990   98022
# 867381  386510.0    80.0   09/22/2003     559950           2780   98008
# 867382  782870.0    70.0   09/09/1985      78000           1400   98116
# 867383  947794.0   320.0   02/22/2002     331681           3010   98059
# 867384  721470.0   820.0   04/15/2005     484950           2620   98077
# 867385  235430.0   782.0   06/01/1984      85000           1500   98027
#
#         PricePerSqFt
# 0         164.429530
# 1          73.355705
# 2           9.855034
# 3         100.000000
# 4         132.812500
# 5         260.955056
# 6         200.561798
# 7          79.775281
# 8         296.629213
# 9          68.268293
# 10        214.390244
# 11        151.583710
# 12        167.375566
# 13         87.307692
# 14        167.375566
# 15         48.642534
# 16        102.916667
# 17         94.093137
# 18        142.132353
# 19        177.551020
# 20        137.755102
# 21        214.285714
# 22        151.020408
# 23         89.201878
# 24        158.685446
# 25        118.577075
# 26        154.150198
# 27       1166.666667
# 28        119.444444
# 29        150.000000
# ...              ...
# 867356     55.184049
# 867357     56.250000
# 867358    123.931624
# 867359    255.882353
# 867360     79.522184
# 867361     49.056604
# 867362    139.240506
# 867363     18.229167
# 867364    114.233577
# 867365    139.160839
# 867366    159.742268
# 867367    141.768229
# 867368     72.988506
# 867369     95.914397
# 867370    230.373832
# 867371    155.709343
# 867372     37.909483
# 867373     56.176471
# 867374     84.971098
# 867375     44.385027
# 867376    234.246575
# 867377    188.679245
# 867378    110.671937
# 867379     35.838150
# 867380     43.216080
# 867381    201.420863
# 867382     55.714286
# 867383    110.193023
# 867384    185.095420
# 867385     56.666667
#
# [867386 rows x 7 columns]

# %% [markdown]
# ### 3. Add a column for PricePerSqFt

# %%
sales_data['PricePerSqFt'] = sales_data['SalePrice']/sales_data['SqFtTotLiving']
sales_data
# Out:
#            Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode  \
# 0       138860.0   110.0   08/21/2014     245000           1490   98002
# 1       138860.0   110.0   06/12/1989     109300           1490   98002
# 2       138860.0   110.0   01/16/2005      14684           1490   98002
# 3       423943.0    50.0   07/15/1999      96000            960   98092
# 4       423943.0    50.0   01/08/2001     127500            960   98092
# 5       403700.0   715.0   07/03/2013     464500           1780   98008
# 6       403700.0   715.0   02/21/2013     357000           1780   98008
# 7       403700.0   715.0   10/13/1995     142000           1780   98008
# 8       403700.0   715.0   02/22/2007     528000           1780   98008
# 9        98400.0   380.0   03/23/1994     139950           2050   98058
# 10       98400.0   380.0   03/29/2017     439500           2050   98058
# 11      330395.0  1610.0   06/07/2012     335000           2210   98038
# 12      330395.0  1610.0   08/26/2013     369900           2210   98038
# 13      330395.0  1610.0   06/27/1994     192950           2210   98038
# 14      330395.0  1610.0   08/22/2013     369900           2210   98038
# 15      330395.0  1610.0   11/10/1993     107500           2210   98038
# 16      675260.0   940.0   03/06/1998     209950           2040   98031
# 17      675260.0   940.0   08/01/1995     191950           2040   98031
# 18      675260.0   940.0   09/13/2004     289950           2040   98031
# 19      795508.0   170.0   04/09/2001     174000            980   98058
# 20      795508.0   170.0   10/31/1996     135000            980   98058
# 21      795508.0   170.0   04/30/2004     210000            980   98058
# 22      795508.0   170.0   12/21/2012     148000            980   98058
# 23      638580.0   110.0   07/14/2015     190000           2130   98188
# 24      638580.0   110.0   12/21/2015     338000           2130   98188
# 25      252206.0  9011.0   02/21/1997     300000           2530   98051
# 26      252206.0  9011.0   11/28/2000     390000           2530   98051
# 27      321165.0    50.0   05/10/2004    2100000           1800   98001
# 28      321165.0    50.0   10/24/2013     215000           1800   98001
# 29      321165.0    50.0   09/20/2004     270000           1800   98001
# ...          ...     ...          ...        ...            ...     ...
# 867356  928170.0     5.0   12/11/1986      89950           1630   98116
# 867357  783280.0    60.0   08/21/1986      67500           1200   98146
# 867358  809260.0    80.0   08/20/2001     145000           1170   98042
# 867359  344800.0  1500.0   07/12/1996     174000            680   98125
# 867360  177421.0   370.0   06/24/1993     233000           2930   98077
# 867361  278731.0   900.0   10/18/1982      78000           1590   98031
# 867362   12605.0  9008.0   10/01/1993     110000            790   98072
# 867363   42506.0  9158.0   03/07/1988      35000           1920   98053
# 867364  955020.0  4120.0   03/24/1994     156500           1370   98105
# 867365  220750.0   450.0   05/19/1993     199000           1430   98102
# 867366  546878.0   130.0   03/23/2005     309900           1940   98042
# 867367  251700.0   900.0   07/05/2005     272195           1920   98042
# 867368  881990.0   515.0   09/25/1985      63500            870   98105
# 867369  222505.0  9207.0   10/09/1995     246500           2570   98005
# 867370  222505.0  9207.0   10/09/1995     246500           1070   98005
# 867371  541860.0    20.0   07/23/2002     450000           2890   98115
# 867372  172606.0  9181.0   07/26/1983      87950           2320   98077
# 867373  293500.0   100.0   01/23/1987      66850           1190   98001
# 867374   80900.0  1440.0   10/19/1988     147000           1730   98109
# 867375  247338.0   310.0   07/27/1987      83000           1870   98058
# 867376   11410.0   629.0   01/26/1998     171000            730   98028
# 867377  568000.0   570.0   01/09/2013     400000           2120   98108
# 867378  944230.0    10.0   10/01/2001     280000           2530   98177
# 867379  797990.0   510.0   09/27/1985      62000           1730   98155
# 867380   42007.0  9047.0   03/09/1988      86000           1990   98022
# 867381  386510.0    80.0   09/22/2003     559950           2780   98008
# 867382  782870.0    70.0   09/09/1985      78000           1400   98116
# 867383  947794.0   320.0   02/22/2002     331681           3010   98059
# 867384  721470.0   820.0   04/15/2005     484950           2620   98077
# 867385  235430.0   782.0   06/01/1984      85000           1500   98027
#
#         PricePerSqFt
# 0         164.429530
# 1          73.355705
# 2           9.855034
# 3         100.000000
# 4         132.812500
# 5         260.955056
# 6         200.561798
# 7          79.775281
# 8         296.629213
# 9          68.268293
# 10        214.390244
# 11        151.583710
# 12        167.375566
# 13         87.307692
# 14        167.375566
# 15         48.642534
# 16        102.916667
# 17         94.093137
# 18        142.132353
# 19        177.551020
# 20        137.755102
# 21        214.285714
# 22        151.020408
# 23         89.201878
# 24        158.685446
# 25        118.577075
# 26        154.150198
# 27       1166.666667
# 28        119.444444
# 29        150.000000
# ...              ...
# 867356     55.184049
# 867357     56.250000
# 867358    123.931624
# 867359    255.882353
# 867360     79.522184
# 867361     49.056604
# 867362    139.240506
# 867363     18.229167
# 867364    114.233577
# 867365    139.160839
# 867366    159.742268
# 867367    141.768229
# 867368     72.988506
# 867369     95.914397
# 867370    230.373832
# 867371    155.709343
# 867372     37.909483
# 867373     56.176471
# 867374     84.971098
# 867375     44.385027
# 867376    234.246575
# 867377    188.679245
# 867378    110.671937
# 867379     35.838150
# 867380     43.216080
# 867381    201.420863
# 867382     55.714286
# 867383    110.193023
# 867384    185.095420
# 867385     56.666667
#
# [867386 rows x 7 columns]

# %% [markdown]
# ### 4. Subset the data to 2019 sales only.
#
# We can assume that the DocumentDate is approximately the sale date.

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867386 entries, 0 to 867385
# Data columns (total 7 columns):
# Major            867386 non-null float64
# Minor            867386 non-null float64
# DocumentDate     867386 non-null object
# SalePrice        867386 non-null int64
# SqFtTotLiving    867386 non-null int64
# ZipCode          867386 non-null object
# PricePerSqFt     867386 non-null float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 46.3+ MB

# %%
sales_data['Year'] = sales_data['DocumentDate'].str[-4:]
sales_data
# Out:
#            Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode  \
# 0       138860.0   110.0   08/21/2014     245000           1490   98002
# 1       138860.0   110.0   06/12/1989     109300           1490   98002
# 2       138860.0   110.0   01/16/2005      14684           1490   98002
# 3       423943.0    50.0   07/15/1999      96000            960   98092
# 4       423943.0    50.0   01/08/2001     127500            960   98092
# 5       403700.0   715.0   07/03/2013     464500           1780   98008
# 6       403700.0   715.0   02/21/2013     357000           1780   98008
# 7       403700.0   715.0   10/13/1995     142000           1780   98008
# 8       403700.0   715.0   02/22/2007     528000           1780   98008
# 9        98400.0   380.0   03/23/1994     139950           2050   98058
# 10       98400.0   380.0   03/29/2017     439500           2050   98058
# 11      330395.0  1610.0   06/07/2012     335000           2210   98038
# 12      330395.0  1610.0   08/26/2013     369900           2210   98038
# 13      330395.0  1610.0   06/27/1994     192950           2210   98038
# 14      330395.0  1610.0   08/22/2013     369900           2210   98038
# 15      330395.0  1610.0   11/10/1993     107500           2210   98038
# 16      675260.0   940.0   03/06/1998     209950           2040   98031
# 17      675260.0   940.0   08/01/1995     191950           2040   98031
# 18      675260.0   940.0   09/13/2004     289950           2040   98031
# 19      795508.0   170.0   04/09/2001     174000            980   98058
# 20      795508.0   170.0   10/31/1996     135000            980   98058
# 21      795508.0   170.0   04/30/2004     210000            980   98058
# 22      795508.0   170.0   12/21/2012     148000            980   98058
# 23      638580.0   110.0   07/14/2015     190000           2130   98188
# 24      638580.0   110.0   12/21/2015     338000           2130   98188
# 25      252206.0  9011.0   02/21/1997     300000           2530   98051
# 26      252206.0  9011.0   11/28/2000     390000           2530   98051
# 27      321165.0    50.0   05/10/2004    2100000           1800   98001
# 28      321165.0    50.0   10/24/2013     215000           1800   98001
# 29      321165.0    50.0   09/20/2004     270000           1800   98001
# ...          ...     ...          ...        ...            ...     ...
# 867356  928170.0     5.0   12/11/1986      89950           1630   98116
# 867357  783280.0    60.0   08/21/1986      67500           1200   98146
# 867358  809260.0    80.0   08/20/2001     145000           1170   98042
# 867359  344800.0  1500.0   07/12/1996     174000            680   98125
# 867360  177421.0   370.0   06/24/1993     233000           2930   98077
# 867361  278731.0   900.0   10/18/1982      78000           1590   98031
# 867362   12605.0  9008.0   10/01/1993     110000            790   98072
# 867363   42506.0  9158.0   03/07/1988      35000           1920   98053
# 867364  955020.0  4120.0   03/24/1994     156500           1370   98105
# 867365  220750.0   450.0   05/19/1993     199000           1430   98102
# 867366  546878.0   130.0   03/23/2005     309900           1940   98042
# 867367  251700.0   900.0   07/05/2005     272195           1920   98042
# 867368  881990.0   515.0   09/25/1985      63500            870   98105
# 867369  222505.0  9207.0   10/09/1995     246500           2570   98005
# 867370  222505.0  9207.0   10/09/1995     246500           1070   98005
# 867371  541860.0    20.0   07/23/2002     450000           2890   98115
# 867372  172606.0  9181.0   07/26/1983      87950           2320   98077
# 867373  293500.0   100.0   01/23/1987      66850           1190   98001
# 867374   80900.0  1440.0   10/19/1988     147000           1730   98109
# 867375  247338.0   310.0   07/27/1987      83000           1870   98058
# 867376   11410.0   629.0   01/26/1998     171000            730   98028
# 867377  568000.0   570.0   01/09/2013     400000           2120   98108
# 867378  944230.0    10.0   10/01/2001     280000           2530   98177
# 867379  797990.0   510.0   09/27/1985      62000           1730   98155
# 867380   42007.0  9047.0   03/09/1988      86000           1990   98022
# 867381  386510.0    80.0   09/22/2003     559950           2780   98008
# 867382  782870.0    70.0   09/09/1985      78000           1400   98116
# 867383  947794.0   320.0   02/22/2002     331681           3010   98059
# 867384  721470.0   820.0   04/15/2005     484950           2620   98077
# 867385  235430.0   782.0   06/01/1984      85000           1500   98027
#
#         PricePerSqFt  Year
# 0         164.429530  2014
# 1          73.355705  1989
# 2           9.855034  2005
# 3         100.000000  1999
# 4         132.812500  2001
# 5         260.955056  2013
# 6         200.561798  2013
# 7          79.775281  1995
# 8         296.629213  2007
# 9          68.268293  1994
# 10        214.390244  2017
# 11        151.583710  2012
# 12        167.375566  2013
# 13         87.307692  1994
# 14        167.375566  2013
# 15         48.642534  1993
# 16        102.916667  1998
# 17         94.093137  1995
# 18        142.132353  2004
# 19        177.551020  2001
# 20        137.755102  1996
# 21        214.285714  2004
# 22        151.020408  2012
# 23         89.201878  2015
# 24        158.685446  2015
# 25        118.577075  1997
# 26        154.150198  2000
# 27       1166.666667  2004
# 28        119.444444  2013
# 29        150.000000  2004
# ...              ...   ...
# 867356     55.184049  1986
# 867357     56.250000  1986
# 867358    123.931624  2001
# 867359    255.882353  1996
# 867360     79.522184  1993
# 867361     49.056604  1982
# 867362    139.240506  1993
# 867363     18.229167  1988
# 867364    114.233577  1994
# 867365    139.160839  1993
# 867366    159.742268  2005
# 867367    141.768229  2005
# 867368     72.988506  1985
# 867369     95.914397  1995
# 867370    230.373832  1995
# 867371    155.709343  2002
# 867372     37.909483  1983
# 867373     56.176471  1987
# 867374     84.971098  1988
# 867375     44.385027  1987
# 867376    234.246575  1998
# 867377    188.679245  2013
# 867378    110.671937  2001
# 867379     35.838150  1985
# 867380     43.216080  1988
# 867381    201.420863  2003
# 867382     55.714286  1985
# 867383    110.193023  2002
# 867384    185.095420  2005
# 867385     56.666667  1984
#
# [867386 rows x 8 columns]

# %% [markdown]
# ### 5. Subset the data to zip codes within the City of Seattle.
#
# You'll need to find a list of Seattle zip codes!

# %%
seattle_zips = pd.read_csv('Zip_Codes.csv')
seattle_zips['ZIP'] = seattle_zips['ZIP'].astype(str)

# %%
seattle_zip_list = list(seattle_zips['ZIP'])
seattle_zip_list
# Out:
# ['98001',
#  '98002',
#  '98003',
#  '98004',
#  '98005',
#  '98006',
#  '98007',
#  '98008',
#  '98010',
#  '98011',
#  '98012',
#  '98014',
#  '98019',
#  '98020',
#  '98021',
#  '98022',
#  '98022',
#  '98023',
#  '98024',
#  '98026',
#  '98027',
#  '98028',
#  '98029',
#  '98030',
#  '98031',
#  '98032',
#  '98033',
#  '98034',
#  '98036',
#  '98037',
#  '98038',
#  '98039',
#  '98040',
#  '98042',
#  '98043',
#  '98045',
#  '98047',
#  '98047',
#  '98051',
#  '98052',
#  '98053',
#  '98055',
#  '98056',
#  '98057',
#  '98058',
#  '98059',
#  '98065',
#  '98068',
#  '98070',
#  '98072',
#  '98072',
#  '98074',
#  '98075',
#  '98077',
#  '98077',
#  '98087',
#  '98092',
#  '98092',
#  '98101',
#  '98102',
#  '98103',
#  '98104',
#  '98105',
#  '98106',
#  '98107',
#  '98108',
#  '98109',
#  '98110',
#  '98112',
#  '98115',
#  '98116',
#  '98117',
#  '98118',
#  '98119',
#  '98121',
#  '98122',
#  '98125',
#  '98126',
#  '98133',
#  '98134',
#  '98136',
#  '98144',
#  '98146',
#  '98148',
#  '98154',
#  '98155',
#  '98158',
#  '98164',
#  '98166',
#  '98168',
#  '98177',
#  '98178',
#  '98188',
#  '98195',
#  '98198',
#  '98199',
#  '98201',
#  '98203',
#  '98204',
#  '98205',
#  '98206',
#  '98208',
#  '98223',
#  '98224',
#  '98241',
#  '98251',
#  '98252',
#  '98258',
#  '98270',
#  '98271',
#  '98272',
#  '98275',
#  '98282',
#  '98288',
#  '98290',
#  '98292',
#  '98294',
#  '98296',
#  '98303',
#  '98304',
#  '98310',
#  '98311',
#  '98312',
#  '98314',
#  '98315',
#  '98321',
#  '98323',
#  '98327',
#  '98328',
#  '98329',
#  '98330',
#  '98332',
#  '98333',
#  '98335',
#  '98337',
#  '98338',
#  '98340',
#  '98342',
#  '98345',
#  '98346',
#  '98349',
#  '98351',
#  '98354',
#  '98354',
#  '98359',
#  '98360',
#  '98366',
#  '98367',
#  '98370',
#  '98371',
#  '98372',
#  '98373',
#  '98374',
#  '98375',
#  '98380',
#  '98383',
#  '98385',
#  '98387',
#  '98388',
#  '98390',
#  '98391',
#  '98392',
#  '98394',
#  '98396',
#  '98397',
#  '98402',
#  '98403',
#  '98404',
#  '98405',
#  '98406',
#  '98407',
#  '98408',
#  '98409',
#  '98416',
#  '98418',
#  '98421',
#  '98422',
#  '98422',
#  '98424',
#  '98430',
#  '98433',
#  '98438',
#  '98439',
#  '98443',
#  '98444',
#  '98445',
#  '98446',
#  '98447',
#  '98465',
#  '98466',
#  '98467',
#  '98498',
#  '98499',
#  '98580',
#  '98922',
#  '98925',
#  '98926',
#  '98934',
#  '98940',
#  '98941',
#  '98943',
#  '98946',
#  '98950']

# %%
sales_data_seattle = sales_data[sales_data['ZipCode'].isin(seattle_zip_list)]
sales_data_seattle
# Out:
#            Major   Minor DocumentDate  SalePrice  SqFtTotLiving ZipCode  \
# 0       138860.0   110.0   08/21/2014     245000           1490   98002
# 1       138860.0   110.0   06/12/1989     109300           1490   98002
# 2       138860.0   110.0   01/16/2005      14684           1490   98002
# 3       423943.0    50.0   07/15/1999      96000            960   98092
# 4       423943.0    50.0   01/08/2001     127500            960   98092
# 5       403700.0   715.0   07/03/2013     464500           1780   98008
# 6       403700.0   715.0   02/21/2013     357000           1780   98008
# 7       403700.0   715.0   10/13/1995     142000           1780   98008
# 8       403700.0   715.0   02/22/2007     528000           1780   98008
# 9        98400.0   380.0   03/23/1994     139950           2050   98058
# 10       98400.0   380.0   03/29/2017     439500           2050   98058
# 11      330395.0  1610.0   06/07/2012     335000           2210   98038
# 12      330395.0  1610.0   08/26/2013     369900           2210   98038
# 13      330395.0  1610.0   06/27/1994     192950           2210   98038
# 14      330395.0  1610.0   08/22/2013     369900           2210   98038
# 15      330395.0  1610.0   11/10/1993     107500           2210   98038
# 16      675260.0   940.0   03/06/1998     209950           2040   98031
# 17      675260.0   940.0   08/01/1995     191950           2040   98031
# 18      675260.0   940.0   09/13/2004     289950           2040   98031
# 19      795508.0   170.0   04/09/2001     174000            980   98058
# 20      795508.0   170.0   10/31/1996     135000            980   98058
# 21      795508.0   170.0   04/30/2004     210000            980   98058
# 22      795508.0   170.0   12/21/2012     148000            980   98058
# 23      638580.0   110.0   07/14/2015     190000           2130   98188
# 24      638580.0   110.0   12/21/2015     338000           2130   98188
# 25      252206.0  9011.0   02/21/1997     300000           2530   98051
# 26      252206.0  9011.0   11/28/2000     390000           2530   98051
# 27      321165.0    50.0   05/10/2004    2100000           1800   98001
# 28      321165.0    50.0   10/24/2013     215000           1800   98001
# 29      321165.0    50.0   09/20/2004     270000           1800   98001
# ...          ...     ...          ...        ...            ...     ...
# 867354  882290.0    90.0   10/11/1985      81750           2700   98125
# 867355  149830.0  1035.0   08/10/1988      60000           1140   98144
# 867356  928170.0     5.0   12/11/1986      89950           1630   98116
# 867357  783280.0    60.0   08/21/1986      67500           1200   98146
# 867358  809260.0    80.0   08/20/2001     145000           1170   98042
# 867359  344800.0  1500.0   07/12/1996     174000            680   98125
# 867360  177421.0   370.0   06/24/1993     233000           2930   98077
# 867361  278731.0   900.0   10/18/1982      78000           1590   98031
# 867362   12605.0  9008.0   10/01/1993     110000            790   98072
# 867363   42506.0  9158.0   03/07/1988      35000           1920   98053
# 867364  955020.0  4120.0   03/24/1994     156500           1370   98105
# 867365  220750.0   450.0   05/19/1993     199000           1430   98102
# 867366  546878.0   130.0   03/23/2005     309900           1940   98042
# 867367  251700.0   900.0   07/05/2005     272195           1920   98042
# 867368  881990.0   515.0   09/25/1985      63500            870   98105
# 867369  222505.0  9207.0   10/09/1995     246500           2570   98005
# 867370  222505.0  9207.0   10/09/1995     246500           1070   98005
# 867372  172606.0  9181.0   07/26/1983      87950           2320   98077
# 867373  293500.0   100.0   01/23/1987      66850           1190   98001
# 867374   80900.0  1440.0   10/19/1988     147000           1730   98109
# 867375  247338.0   310.0   07/27/1987      83000           1870   98058
# 867376   11410.0   629.0   01/26/1998     171000            730   98028
# 867377  568000.0   570.0   01/09/2013     400000           2120   98108
# 867378  944230.0    10.0   10/01/2001     280000           2530   98177
# 867379  797990.0   510.0   09/27/1985      62000           1730   98155
# 867380   42007.0  9047.0   03/09/1988      86000           1990   98022
# 867381  386510.0    80.0   09/22/2003     559950           2780   98008
# 867382  782870.0    70.0   09/09/1985      78000           1400   98116
# 867383  947794.0   320.0   02/22/2002     331681           3010   98059
# 867385  235430.0   782.0   06/01/1984      85000           1500   98027
#
#         PricePerSqFt  Year
# 0         164.429530  2014
# 1          73.355705  1989
# 2           9.855034  2005
# 3         100.000000  1999
# 4         132.812500  2001
# 5         260.955056  2013
# 6         200.561798  2013
# 7          79.775281  1995
# 8         296.629213  2007
# 9          68.268293  1994
# 10        214.390244  2017
# 11        151.583710  2012
# 12        167.375566  2013
# 13         87.307692  1994
# 14        167.375566  2013
# 15         48.642534  1993
# 16        102.916667  1998
# 17         94.093137  1995
# 18        142.132353  2004
# 19        177.551020  2001
# 20        137.755102  1996
# 21        214.285714  2004
# 22        151.020408  2012
# 23         89.201878  2015
# 24        158.685446  2015
# 25        118.577075  1997
# 26        154.150198  2000
# 27       1166.666667  2004
# 28        119.444444  2013
# 29        150.000000  2004
# ...              ...   ...
# 867354     30.277778  1985
# 867355     52.631579  1988
# 867356     55.184049  1986
# 867357     56.250000  1986
# 867358    123.931624  2001
# 867359    255.882353  1996
# 867360     79.522184  1993
# 867361     49.056604  1982
# 867362    139.240506  1993
# 867363     18.229167  1988
# 867364    114.233577  1994
# 867365    139.160839  1993
# 867366    159.742268  2005
# 867367    141.768229  2005
# 867368     72.988506  1985
# 867369     95.914397  1995
# 867370    230.373832  1995
# 867372     37.909483  1983
# 867373     56.176471  1987
# 867374     84.971098  1988
# 867375     44.385027  1987
# 867376    234.246575  1998
# 867377    188.679245  2013
# 867378    110.671937  2001
# 867379     35.838150  1985
# 867380     43.216080  1988
# 867381    201.420863  2003
# 867382     55.714286  1985
# 867383    110.193023  2002
# 867385     56.666667  1984
#
# [782649 rows x 8 columns]

# %% [markdown]
# ### 6. What is the mean price per square foot for a house sold in Seattle in 2019?
#
# Don't just type the answer. Type code that generates the answer as output!

# %%
sales_data_seattle['PricePerSqFt'].loc[sales_data_seattle['Year'] == '2019'].mean()
# Out:
# 402.88988958518263
